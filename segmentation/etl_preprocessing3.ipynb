# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Введение" data-toc-modified-id="Введение-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Введение</a></span></li><li><span><a href="#1.-🗂️-Загрузка-и--изучение-CSV-файлов" data-toc-modified-id="1.-🗂️-Загрузка-и--изучение-CSV-файлов-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>1. 🗂️ Загрузка и  изучение CSV-файлов</a></span><ul class="toc-item"><li><span><a href="#Выполним-загрузку-и-начальную-предобработки-наших-данных." data-toc-modified-id="Выполним-загрузку-и-начальную-предобработки-наших-данных.-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Выполним загрузку и начальную предобработки наших данных.</a></span></li><li><span><a href="#Посмотрим-на-случайные-строки-наших-данных." data-toc-modified-id="Посмотрим-на-случайные-строки-наших-данных.-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Посмотрим на случайные строки наших данных.</a></span></li></ul></li><li><span><a href="#Обработка-пропусков-и-аномалий" data-toc-modified-id="Обработка-пропусков-и-аномалий-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Обработка пропусков и аномалий</a></span><ul class="toc-item"><li><span><a href="#Датафрейм-closed_deals" data-toc-modified-id="Датафрейм-closed_deals-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Датафрейм <code>closed_deals</code></a></span></li><li><span><a href="#Таблица:-marketing_qualified" data-toc-modified-id="Таблица:-marketing_qualified-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Таблица: <code>marketing_qualified</code></a></span></li><li><span><a href="#Таблица:-orders" data-toc-modified-id="Таблица:-orders-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Таблица: <code>orders</code></a></span></li><li><span><a href="#Таблица:-order_reviews" data-toc-modified-id="Таблица:-order_reviews-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Таблица: <code>order_reviews</code></a></span></li><li><span><a href="#Таблица:-products" data-toc-modified-id="Таблица:-products-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Таблица: <code>products</code></a></span></li></ul></li><li><span><a href="#Приведение-типов-и-стандартизация" data-toc-modified-id="Приведение-типов-и-стандартизация-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Приведение типов и стандартизация</a></span><ul class="toc-item"><li><span><a href="#Оптимизируем-типы-танных." data-toc-modified-id="Оптимизируем-типы-танных.-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Оптимизируем типы танных.</a></span></li></ul></li><li><span><a href="#Локализация-данных" data-toc-modified-id="Локализация-данных-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Локализация данных</a></span></li><li><span><a href="#Исследовательский-анализ" data-toc-modified-id="Исследовательский-анализ-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Исследовательский анализ</a></span><ul class="toc-item"><li><span><a href="#Количественные-признаки." data-toc-modified-id="Количественные-признаки.-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Количественные признаки.</a></span></li><li><span><a href="#Категориальные-признаки." data-toc-modified-id="Категориальные-признаки.-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Категориальные признаки.</a></span></li><li><span><a href="#Временные-ряды." data-toc-modified-id="Временные-ряды.-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Временные ряды.</a></span></li><li><span><a href="#Корреляции." data-toc-modified-id="Корреляции.-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Корреляции.</a></span></li></ul></li><li><span><a href="#5.-🛠️-Подготовка-к-загрузке-в-Supabase" data-toc-modified-id="5.-🛠️-Подготовка-к-загрузке-в-Supabase-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>5. 🛠️ Подготовка к загрузке в Supabase</a></span><ul class="toc-item"><li><span><a href="#Добавим-словарь-Foreign-Keys." data-toc-modified-id="Добавим-словарь-Foreign-Keys.-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Добавим словарь Foreign Keys.</a></span></li><li><span><a href="#Выполним-проверку-и-очистку-данных." data-toc-modified-id="Выполним-проверку-и-очистку-данных.-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Выполним проверку и очистку данных.</a></span></li></ul></li><li><span><a href="#6.-☁️-Загрузка-данных-в-Supabase-(PostgreSQL)" data-toc-modified-id="6.-☁️-Загрузка-данных-в-Supabase-(PostgreSQL)-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>6. ☁️ Загрузка данных в Supabase (PostgreSQL)</a></span><ul class="toc-item"><li><span><a href="#Выполним-валидацию-результатов" data-toc-modified-id="Выполним-валидацию-результатов-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Выполним валидацию результатов</a></span></li></ul></li><li><span><a href="#✅-Вывод" data-toc-modified-id="✅-Вывод-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>✅ Вывод</a></span></li></ul></div>

# %% [markdown]
# <a id="toc"></a>

# %%
# !jt -t monokai -T -tfs 12 -ofs 10

# %% [markdown]
# # 🔧 Data Preprocessing
#
# ##  Введение
#
# Этот блок отвечает за предобработку сырых CSV-таблиц, полученных из публичного датасета Olist.
# Включает в себя:
# - первичную очистку и стандартизацию колонок,
# - обработку пропусков и дубликатов,
# - извлечение типовой информации о признаках,
# - первичный анализ ключей,
# - подготовку к последующей загрузке в Supabase (PostgreSQL).
#
# ---

# %%
import pandas as pd
import missingno as msno
import os
import re
import warnings  # Отключение предупреждений
from tabulate import tabulate
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import json
warnings.filterwarnings('ignore')  # Отключаем предупреждения

# %% [markdown]
# ## 1. 🗂️ Загрузка и  изучение CSV-файлов
#
# **Используется скрипт `load_and_inspect`**
#
# - Поиск всех `.csv` файлов в указанной директории.
# - Стандартизация имён колонок (`to_snake_case()`).
# - Автоматическое преобразование дат (`convert_dates()`).
# - Удаление полных дубликатов.
# - Поиск потенциальных первичных ключей и очистка по ним.
# - Классификация колонок: даты, текст, числа.
# - Генерация отчёта о пропусках (`missing_report`).
#
# 📌 _Цель: подготовить корректные датафреймы для дальнейшей загрузки и анализа._
#
# ---

# %% [markdown]
# ### Выполним загрузку и начальную предобработки наших данных.

# %%
# Применяем функцию.
from src.data_loader import load_and_inspect
dfs = load_and_inspect(folder_path='datasets')
# Out:
# 📦 Загружается: category_name.csv → `category_name`
# ➡️ Размер: 71 строк × 2 колонок
# 🔁 Полных дубликатов: 0
# ✅ Пропусков нет
# 📅 Дата-признаки: []
# 📝 Текстовые: ['product_category_name', 'product_category_name_english']
# 🔢 Числовые: []
# 🔑 Возможный первичный ключ: product_category_name
# ✅ Дубликатов по ключу `product_category_name` не выявлено.
# ...
#
# 📦 Загружается: closed_deals.csv → `closed_deals`
# ➡️ Размер: 842 строк × 14 колонок
# 🔁 Полных дубликатов: 0
# ⚠️ Пропуски в колонках (%)
# has_company                      92.52
# has_gtin                         92.40
# average_stock                    92.16
# declared_product_catalog_size    91.81
# lead_behaviour_profile           21.02
# business_type                     1.19
# lead_type                         0.71
# business_segment                  0.12
# 📅 Дата-признаки: ['won_date']
# 📝 Текстовые: ['mql_id', 'seller_id', 'sdr_id'] ...
# 🔢 Числовые: ['declared_product_catalog_size', 'declared_monthly_revenue']
# ...

# %% [markdown]
# ### Посмотрим на случайные строки наших данных.

# %%
# Проходим по словарю dfs и выводим 5 случайных строк для каждого датафрейма
for table_name, df in dfs.items():
    print(f" Пример случайных строк для таблицы: {table_name}")
    display(df.sample(n=3, random_state=42).T)  # random_state для воспроизводимости
    print("=" * 125)
# Out:
#  Пример случайных строк для таблицы: category_name
#                                        22             0   \
# product_category_name          cool_stuff   beleza_saude
# product_category_name_english  cool_stuff  health_beauty
#
#                                                              49
# product_category_name          construcao_ferramentas_seguranca
# product_category_name_english         construction_tools_safety
# ...
#  Пример случайных строк для таблицы: closed_deals
#                                                             493  \
# mql_id                         7290c4082936311a3295b7c9ca7bda8f
# seller_id                      9c1c0c36cd23c20897e473901a8fb149
# sdr_id                         9e4d1098a3b0f5da39b0bc48f9876645
# sr_id                          fbf4aef3f6915dc0c3c97d6812522f6a
# won_date                                    2018-03-19 20:26:27
# business_segment                                     food_drink
# ...

# %% [markdown]
# ##  Обработка пропусков и аномалий
# Принятие решений по каждой таблице с учетом анализа пропусков:
#
# Заполнение пропусков в столбцах с различными типами данных, например, для текстовых данных — заполнение значением 'No comment' в столбце review_comment_message.
#
# Удаление колонок с критическим уровнем пропусков (>90%).
#
# Применение более продвинутых техник для числовых и категориальных данных, таких как заполнение медианой для числовых данных с сильной асимметрией или модой для категориальных.
#
# Оставление пропусков в специфичных случаях и создание бинарных индикаторов для отсутствующих значений.
#
# 📌 Цель: обеспечить корректную логику при загрузке данных в базу, учитывать возможную бизнес-интерпретацию пропусков и аномалий, а также предоставить рекомендации по обработке для каждого признака.
#
# ---

# %% [markdown]
# ### Датафрейм `closed_deals`

# %%
# Применим функцию для изучения пропусков
from src.analyze_missing import analyze_missing
analyze_missing(dfs, "closed_deals")
# Out:
# 📋 Рекомендации по пропускам для датафрейма: 'closed_deals'
#
# Колонка                          % Пропусков  Тип      Рекомендация            Обоснование
# -----------------------------  -------------  -------  ----------------------  ------------------------------
# business_segment                         0.1  object   🔄 Заполнить 'unknown'  Категориальный признак
# lead_type                                0.7  object   🔄 Заполнить 'unknown'  Категориальный признак
# lead_behaviour_profile                  21.0  object   🔄 Заполнить 'unknown'  Категориальный признак
# has_company                             92.5  object   🔥 Удалить колонку      Слишком много пропусков (>90%)
# has_gtin                                92.4  object   🔥 Удалить колонку      Слишком много пропусков (>90%)
# average_stock                           92.2  object   🔥 Удалить колонку      Слишком много пропусков (>90%)
# ...

# %% [markdown]
# 📌 Решения:
#
# - Удалить: has_company, has_gtin, average_stock, declared_product_catalog_size
#
# - Остальное — импутация fillna('unknown') или модой

# %%
# business_segment:
dfs['closed_deals']['business_segment'] = dfs['closed_deals']['business_segment'].fillna('home_decor')

# lead_type:
dfs['closed_deals']['lead_type'] = dfs['closed_deals']['lead_type'].fillna('online_medium')

# lead_behaviour_profile:
dfs['closed_deals']['lead_behaviour_profile'] = dfs['closed_deals']['lead_behaviour_profile'].fillna('cat')

# has_company:
#dfs['closed_deals'].drop(columns=['has_company'], inplace=True)

# has_gtin:
#dfs['closed_deals'].drop(columns=['has_gtin'], inplace=True)

# average_stock:
dfs['closed_deals'].drop(columns=['average_stock'], inplace=True)

# business_type:
dfs['closed_deals']['business_type'] = dfs['closed_deals']['business_type'].fillna('reseller')

# declared_product_catalog_size:
#dfs['closed_deals'].drop(columns=['declared_product_catalog_size'], inplace=True)
print(f"Пропусков осталось {dfs['closed_deals'].isna().sum().sum()}")
# Out:
# Пропусков осталось 2330

# %% [markdown]
# ### Таблица: `marketing_qualified`

# %%
# Применим функцию для изучения пропусков
analyze_missing(dfs, "marketing_qualified")
# Out:
# 📋 Рекомендации по пропускам для датафрейма: 'marketing_qualified'
#
# Колонка      % Пропусков  Тип     Рекомендация            Обоснование
# ---------  -------------  ------  ----------------------  ----------------------
# origin               0.8  object  🔄 Заполнить 'unknown'  Категориальный признак
#
# 💡 Генерация кода для применения:
#
# # origin:
# dfs['marketing_qualified']['origin'] = dfs['marketing_qualified']['origin'].fillna('unknown')
#
#
# ✅ Явных корреляций между пропусками не найдено.

# %% [markdown]
# 📌 Решения::
#
# - origin.fillna('unknown') — безопасно, не искажает распределение.

# %%
# Работаем напрямую с копией внутри словаря
dfs['marketing_qualified']['origin'] = dfs['marketing_qualified']['origin'].fillna('unknown')
print(f"Пропусков осталось {dfs['marketing_qualified'].isna().sum().sum()}")
# Out:
# Пропусков осталось 0

# %% [markdown]
# ### Таблица: `orders`

# %%
# Применим функцию для изучения пропусков
analyze_missing(dfs, "orders")
# Out:
# 📋 Рекомендации по пропускам для датафрейма: 'orders'
#
# Колонка                          % Пропусков  Тип             Рекомендация             Обоснование
# -----------------------------  -------------  --------------  -----------------------  ----------------------
# order_approved_at                        0.2  object          🔄 Заполнить 'unknown'   Категориальный признак
# order_delivered_carrier_date             1.8  datetime64[ns]  🕒 Заполнить ближайшими  Длинный временной ряд
# order_delivered_customer_date            3.0  datetime64[ns]  🕒 Заполнить ближайшими  Длинный временной ряд
#
# 💡 Генерация кода для применения:
#
# # order_approved_at:
# dfs['orders']['order_approved_at'] = dfs['orders']['order_approved_at'].fillna('unknown')
#
# # order_delivered_carrier_date:
# dfs['orders']['order_delivered_carrier_date'] = dfs['orders']['order_delivered_carrier_date'].fillna(method='ffill').fillna(method='bfill')
#
# # order_delivered_customer_date:
# ...

# %% [markdown]
# 📌 Решения:
#
# - Оставляем как есть, пропуски связаны со статусом заказа.

# %% [markdown]
# ### Таблица: `order_reviews`

# %%
# Применим функцию для изучения пропусков
analyze_missing(dfs, "order_reviews")
print(f"Пропусков осталось {dfs['order_reviews'].isna().sum().sum()}")
# Out:
# 📋 Рекомендации по пропускам для датафрейма: 'order_reviews'
#
# Колонка                   % Пропусков  Тип     Рекомендация            Обоснование
# ----------------------  -------------  ------  ----------------------  ----------------------
# review_comment_title             88.3  object  🔄 Заполнить 'unknown'  Категориальный признак
# review_comment_message           58.7  object  🔄 Заполнить 'unknown'  Категориальный признак
#
# 💡 Генерация кода для применения:
#
# # review_comment_title:
# dfs['order_reviews']['review_comment_title'] = dfs['order_reviews']['review_comment_title'].fillna('unknown')
#
# # review_comment_message:
# dfs['order_reviews']['review_comment_message'] = dfs['order_reviews']['review_comment_message'].fillna('unknown')
#
#
# ✅ Явных корреляций между пропусками не найдено.
# Пропусков осталось 145903

# %% [markdown]
# 📌 Решения:
#
# - Необязательный поля —  заполним на "unknown".

# %%
# review_comment_title:
dfs['order_reviews']['review_comment_title'] = dfs['order_reviews']['review_comment_title'].fillna('unknown')

# review_comment_message:
dfs['order_reviews']['review_comment_message'] = dfs['order_reviews']['review_comment_message'].fillna('unknown')

# %% [markdown]
# ### Таблица: `products`

# %%
analyze_missing(dfs, "products")
# Out:
# 📋 Рекомендации по пропускам для датафрейма: 'products'
#
# Колонка                       % Пропусков  Тип      Рекомендация            Обоснование
# --------------------------  -------------  -------  ----------------------  --------------------------------------------
# product_category_name                 1.9  object   🔄 Заполнить 'unknown'  Категориальный признак
# product_name_lenght                   1.9  float64  🟢 Заполнить средним    Числовой признак с нормальным распределением
# product_description_lenght            1.9  float64  🟢 Заполнить средним    Числовой признак с нормальным распределением
# product_photos_qty                    1.9  float64  🟡 Заполнить медианой   Числовой признак с асимметрией
# product_weight_g                      0.0  float64  🟡 Заполнить медианой   Числовой признак с асимметрией
# product_length_cm                     0.0  float64  🟢 Заполнить средним    Числовой признак с нормальным распределением
# ...

# %% [markdown]
# 📌 Решения:
#
# - Малые пропуски (0.006%) — заменить медианой по product_category_name.
#
# - Пропуски в product_category_name можно заменить на 'unknown'.
#
# - Длины названия/описания — либо оставить, либо пересчитать при наличии product_name, product_description.

# %%
# Работаем напрямую с копией внутри словаря
dfs['products'] = dfs['products'].copy()

# product_category_name: NaN → 'unknown'
dfs['products']['product_category_name'] = dfs['products']['product_category_name'].fillna('unknown')

# Заполнение product_name_lenght медианой
dfs['products']['product_name_lenght'] = dfs['products']['product_name_lenght'].fillna(
    dfs['products']['product_name_lenght'].median()
)

# Заполнение product_description_lenght медианой
dfs['products']['product_description_lenght'] = dfs['products']['product_description_lenght'].fillna(
    dfs['products']['product_description_lenght'].median()
)

# product_photos_qty: пропуски → 0
dfs['products']['product_photos_qty'] = dfs['products']['product_photos_qty'].fillna(0).astype(int)

# Заполнение размеров и веса медианой в категории
dim_cols = ['product_weight_g', 'product_length_cm', 'product_height_cm', 'product_width_cm']
for col in dim_cols:
    dfs['products'][col] = dfs['products'].groupby('product_category_name')[col]\
                                          .transform(lambda x: x.fillna(x.median()))
print(f"Пропусков осталось {dfs['products'].isna().sum().sum()}")
# Out:
# Пропусков осталось 0

# %% [markdown]
# ## Приведение типов и стандартизация
#
# - Проверка и явное преобразование типов:
#   - `datetime` для всех дат.
#   - `int/float` для числовых значений (`payment_value`, `price`, и т.д.).
#   - `category` для фиксированных наборов (например, `product_category_name`).
# - Явная типизация для логических признаков (`is_delivered`, `has_comment`, и т.п.).
#
# 📌 _Цель: оптимизация памяти и подготовка к загрузке СУБД._
#
# ---

# %% [markdown]
# ### Оптимизируем типы танных.

# %%
# Применение функции
from src.optimize_data_types import optimize_data_type

# Зададим словарь для принудительного приведения типов по окончанию
dtype_rules = {'_id': 'str',
               '_at': 'datetime',
               '_city': 'category',
               '_title':'str',
               '_message':'str',
               '_gtin':'bool',
               '_company':'bool'}

# Применим скрипт
dfso, reports = optimize_data_type(dfs, dtype_rules=dtype_rules, verbose=True)
# Out:
# 📊 Отчет оптимизации для: category_name
#
# ℹ️ Изменений типов данных не обнаружено
#
# 💾 Статистика использования памяти:
# -----------------------  -------------
# Исходный размер          0.01 MB
# Оптимизированный размер  0.01 MB
# Экономия памяти          0.00 MB(0.0%)
# -----------------------  -------------
#
# 📈 Общая статистика:
# • Колонок: 2
# • Строк: 71
# • Оптимизировано колонок: 0
# ...
#
# 📊 Отчет оптимизации для: closed_deals
#
# 🔀 Изменения типов данных:
# Колонка                   Исходный тип    Новый тип
# ------------------------  --------------  -----------
# business_segment          object          category
# lead_type                 object          category
# lead_behaviour_profile    object          category
# has_company               object          bool
# has_gtin                  object          bool
# business_type             object          category
# declared_monthly_revenue  float64         int32
#
# 💾 Статистика использования памяти:
# ...

# %% [markdown]
# ##  Локализация данных
# 📌 _Цель: Для лучшего понимания бизнес процессов._
#
# ---

# %% [markdown]
# Мы предварительно загрузили в нейросеть уникальные названия категорий и выполнили сохранение получившихся словарей в JSON формате.

# %%
# Загрузка JSON файлов
with open('translation.json', 'r', encoding='utf-8') as f:
    translation = json.load(f)
    
# Выводим первые элементы каждого раздела
for dict_name, data in translation.items():
    print(f"\n=== Первые 3 элемента из {dict_name} ===")
    
    # Преобразуем словарь в список пар (key, value) и берем первые 3 элемента
    first_items = list(data.items())[:3]
    
    for key, value in first_items:
        print(f"{key}: {value}")
# Out:
# === Первые 3 элемента из category_translation_dict ===
# health_beauty: красота и здоровье
# computers_accessories: компьютеры и аксессуары
# auto: авто
#
# === Первые 3 элемента из category_group_dict ===
# health_beauty: красота и здоровье
# perfumery: красота и здоровье
# computers_accessories: электроника
#
# === Первые 3 элемента из business_segment_translation ===
# home_decor: домашний декор
# health_beauty: здоровье и красота
# car_accessories: автоаксессуары
#
# === Первые 3 элемента из lead_type_translation ===
# online_medium: онлайн (средний)
# online_big: онлайн (крупный)
# industry: промышленность
#
# === Первые 3 элемента из business_type_translation ===
# reseller: реселлер
# manufacturer: производитель
# other: другое
#
# === Первые 3 элемента из origin_translation ===
# organic_search: органика
# paid_search: платный поиск
# social: социальные сети
#
# === Первые 3 элемента из order_status_translation ===
# delivered: доставлен
# shipped: отправлен
# ...

# %%
# Применение к category_name_translated 
dfso['category_name']['category_name_translated'] = (
    dfso['category_name']['product_category_name_english']
    .map(translation["category_translation_dict"])
)

# Применение к category_name_grouped
dfso['category_name']['category_name_grouped'] = (
    dfso['category_name']['product_category_name_english']
    .map(translation["category_group_dict"])
)


# Применим к business_segment
dfso['closed_deals']['business_segment'] = (
    dfso['closed_deals']['business_segment']
    .map(translation['business_segment_translation'])
)    

# Применим к lead_type
dfso['closed_deals']['lead_type'] = (
    dfso['closed_deals']['lead_type']
    .map(translation['lead_type_translation'])
)    

# Применим к 'business_type'
dfso['closed_deals']['business_type'] = (
    dfso['closed_deals']['business_type']
    .map(translation['business_type_translation'])
)

# Применим к 'origin'
dfso['marketing_qualified']['origin'] = (
    dfso['marketing_qualified']['origin']
    .map(translation['origin_translation'])
) 

# Применим к 'order_status'
dfso['orders']['order_status'] = (
    dfso['orders']['order_status']
    .map(translation['order_status_translation'])
) 

# Применим к 'payment_type'
dfso['order_payments']['payment_type'] = (
    dfso['order_payments']['payment_type']
    .map(translation['payment_method_translation'])
) 


# Объединение данных
dfso['products'] = dfso['products'].merge(
    dfso['category_name'], 
    on='product_category_name'
)

# Удаление ненужных колонок
dfso['products'] = dfso['products'].drop(
    columns=['product_category_name']
)

# Удаление временного DataFrame
del dfso['category_name']

# Проверка результата
dfso['products'].sample(5)
# Out:
#                              product_id  product_name_lenght  \
# 31794  f89caa3ea4fb5f7b6e7fb2bb4ba61881                   43
# 5203   94e7891ebd952f90c83f1f27a38dec56                   59
# 30615  8963eba2629ee030c4de83703c0ae020                   60
# 19307  da2d3c0905cbb6888fc1ca9a18f38ba3                   33
# 27220  2cb8d42b598aeb720fc9a0087f69d938                   37
#
#        product_description_lenght  product_photos_qty  product_weight_g  \
# 31794                         187                   1               750
# 5203                         1311                   2                50
# 30615                         303                   2              3450
# 19307                         658                   1              1400
# 27220                         234                   1               300
#
#        product_length_cm  product_height_cm  product_width_cm  \
# 31794                 40                  4                30
# ...

# %% [markdown]
# ## Исследовательский анализ

# %% [markdown]
# ### Количественные признаки.

# %%
from src.numeric_features import analyze_numeric_features
analyze_numeric_features(
    df_dict=dfso,
    bins=50,
    max_sample=10000,
    exclude=['customers', 'geolocation', 'sellers']  # список таблиц, которые исключить
)
# Out:
# ...
# Анализ числовых признаков в таблице: CLOSED_DEALS
# ...
# ╒═══════════════════════════════╤═════════════════╤═══════════════╤═══════════╤═══════════════════════════════════════════════════╕
# │ Признак                       │ Распределение   │   Скошенность │   Выбросы │ Комментарии                                       │
# ╞═══════════════════════════════╪═════════════════╪═══════════════╪═══════════╪═══════════════════════════════════════════════════╡
# │ declared_product_catalog_size │ lognorm         │          2.67 │         6 │ Распределение не похоже на нормальное (p ≤ 0.05). │
# │                               │                 │               │           │ Обнаружено много выбросов: 6 (8.7%).              │
# │                               │                 │               │           │ Сильная скошенность (skew = 2.67).                │
# │                               │                 │               │           │ Наилучшее распределение по ММП: lognorm.          │
# ...

# %% [markdown]
# ### Категориальные признаки.

# %%
from src.categorical_features import analyze_categorical_features
report = analyze_categorical_features(
    df_dict=dfso,
    top_n=5,
    max_cardinality=30,
    palette='Blues',
    exclude_tables=[''],
    exclude_columns=['sr_id', 'session_id']
)
# Out:
# ...
# Анализ таблицы: CLOSED_DEALS
# ...
# +-------------------------+--------------------------+
# | Метрика                 | Значение                 |
# +=========================+==========================+
# | Всего записей:          | 842                      |
# +-------------------------+--------------------------+
# | Уникальных значений:    | 8                        |
# +-------------------------+--------------------------+
# | Пропуски:               | 0 (0.0%)                 |
# +-------------------------+--------------------------+
# | Доминирующая категория: | онлайн (средний) (40.1%) |
# +-------------------------+--------------------------+
# +-------------------------+-------------+
# | Метрика                 | Значение    |
# +=========================+=============+
# | Всего записей:          | 842         |
# +-------------------------+-------------+
# | Уникальных значений:    | 9           |
# +-------------------------+-------------+
# ...

# %% [markdown]
# ### Временные ряды.

# %%
from src.time_features import time_series_eda
time_series_eda(dfso, time_freq='W', save_plots=False)
# Out:
# ...
# Анализ таблицы: CLOSED_DEALS
# ...
# 📅 Временной диапазон для 'won_date':
#    Начало: 2017-12-05 02:00:00
#    Конец:  2018-11-14 18:04:19
# 🔍 Обнаружены пропуски: 49 периодов.
# → Тренд: 📉 Падение (наклон = -0.06)
# 📝 Автокомментарии:
#  - ⚠️ Данные показывают колебания, возможна сезонность или нестабильность.
#  - ⚠️ Обнаружены пропуски данных в 49 периодах.
#
# ...
# Анализ таблицы: MARKETING_QUALIFIED
# ...
# 📅 Временной диапазон для 'first_contact_date':
#    Начало: 2017-06-14 00:00:00
#    Конец:  2018-05-31 00:00:00
# 🔍 Обнаружены пропуски: 0 периодов.
# → Тренд: 📈 Рост (наклон = 0.90)
# 📝 Автокомментарии:
#  - ⚠️ Данные показывают колебания, возможна сезонность или нестабильность.
#
# ...
# Анализ таблицы: ORDERS
# ...
# 📅 Временной диапазон для 'order_purchase_timestamp':
#    Начало: 2016-09-04 21:15:19
#    Конец:  2018-10-17 17:30:18
# 🔍 Обнаружены пропуски: 110 периодов.
# → Тренд: 📈 Рост (наклон = 1.69)
# 📝 Автокомментарии:
# ...

# %% [markdown]
# ### Корреляции.

# %%
from src.corr_features import analyze_correlations
analyze_correlations(dfso, method="pearson", threshold=0.5)
# Out:
# ...
# Анализ корреляций для таблицы: CLOSED_DEALS
# ...
# Нет сильно коррелирующих признаков по выбранному порогу.
#
# ...
# Анализ корреляций для таблицы: CUSTOMERS
# ...
# Нет сильно коррелирующих признаков по выбранному порогу.
#
# ...
# Анализ корреляций для таблицы: GEOLOCATION
# ...
# Нет сильно коррелирующих признаков по выбранному порогу.
#
# ...
# Анализ корреляций для таблицы: MARKETING_QUALIFIED
# ...
# Нет числовых признаков в таблице marketing_qualified. Пропускаем.
#
# ...
# Анализ корреляций для таблицы: ORDERS
# ...
# Нет числовых признаков в таблице orders. Пропускаем.
#
# ...
# Анализ корреляций для таблицы: ORDER_ITEMS
# ...
# Нет сильно коррелирующих признаков по выбранному порогу.
#
# ...
# Анализ корреляций для таблицы: ORDER_PAYMENTS
# ...
# Нет сильно коррелирующих признаков по выбранному порогу.
#
# ...
# Анализ корреляций для таблицы: ORDER_REVIEWS
# ...
# Нет сильно коррелирующих признаков по выбранному порогу.
#
# ...
# Анализ корреляций для таблицы: PRODUCTS
# ...
# product_weight_g и product_height_cm: прямая корреляция 0.56 (pearson)
# ...

# %% [markdown]
# ## 5. 🛠️ Подготовка к загрузке в Supabase
#
# - Ручная проверка нормализованной схемы таблиц.
# - Проверка первичных и внешних ключей.
# - Генерация схемы таблиц (DDL) для PostgreSQL (или автоматическая миграция).
# - Сопоставление колонок с типами (`VARCHAR`, `INTEGER`, `TIMESTAMP`, `FLOAT`, `BOOLEAN`).
#
# 📌 _Цель: привести структуру к формату, пригодному для аналитической базы данных._
#
# ---

# %% [markdown]
# ### Добавим словарь Foreign Keys.

# %%
# Словарь первичных ключей
pk = {
    "order_items": ["order_id", "order_item_id"],
    "orders": ["order_id"],
    "customers": ["customer_id"],
    "products": ["product_id"],
    "order_reviews": ["review_id"],
    "sellers": ["seller_id"],
    "closed_deals": ["mql_id"]
}

# Словарь вторичных ключей
fk = {  
    "order_items": {
        "order_id": "orders(order_id)",
        "product_id": "products(product_id)",
        "seller_id": "sellers(seller_id)"
    },
    "orders": {
        "customer_id": "customers(customer_id)",
    },
    "order_reviews": {
        "order_id": "orders(order_id)"
    },
    "order_payments": {
        "order_id": "orders(order_id)"
    },
#    "customers": {
#        "zip": "geolocation(zip)"
#    },
#    "sellers": {
#        "zip": "geolocation(zip)"
#   },
    
    "closed_deals": {
        "seller_id": "sellers(seller_id)"  
    },
    "marketing_qualified": {
        "mql_id": "closed_deals(mql_id)"
    }
}

# %% [markdown]
# ### Выполним проверку и очистку данных.

# %%
def validate_and_clean_data(
    dfso: dict, 
    fk_dict: dict,
    verbose: bool = True
) -> tuple[dict, dict]:
    """
    Автоматическая проверка и очистка данных на основе словаря внешних ключей
    
    Параметры:
        dfso: Словарь с DataFrame
        fk_dict: Словарь внешних ключей в формате {таблица: {столбец: ссылка}}
        verbose: Флаг вывода подробной информации
        
    Возвращает:
        Кортеж (очищенные данные, статистика удалений)
    """
    
    stats = {}
    cleaned_dfs = dfso.copy()
    
    # Проход по всем таблицам с FK
    for child_table, fks in fk_dict.items():
        if child_table not in cleaned_dfs:
            if verbose:
                print(f"⚠️ Таблица {child_table} отсутствует в данных, пропускаем...")
            continue
            
        df = cleaned_dfs[child_table].copy()
        initial_count = len(df)
        
        for fk_column, ref in fks.items():
            # Парсим ссылку: parent_table(parent_column)
            ref_match = re.match(r"(\w+)\((\w+)\)", ref)
            if not ref_match:
                raise ValueError(f"Некорректный формат ссылки: {ref}")
                
            parent_table, parent_column = ref_match.groups()
            
            # Проверка существования родительской таблицы
            if parent_table not in cleaned_dfs:
                raise ValueError(f"Родительская таблица {parent_table} не найдена")
                
            # Получаем валидные ключи
            valid_keys = set(cleaned_dfs[parent_table][parent_column].unique())
            
            # Фильтрация данных
            mask = df[fk_column].isin(valid_keys)
            invalid_count = (~mask).sum()
            
            if verbose:
                print(f"🔍 {child_table}.{fk_column} → {parent_table}.{parent_column}")
                print(f"   Найдено некорректных записей: {invalid_count} ({invalid_count/len(df):.1%})")
                
            df = df[mask].copy()
            
            # Обновляем статистику
            stats_key = f"{child_table}.{fk_column}"
            stats[stats_key] = stats.get(stats_key, 0) + invalid_count
            
        # Сохраняем очищенные данные
        cleaned_dfs[child_table] = df
        if verbose:
            print(f"✅ {child_table}: Удалено {initial_count - len(df)} записей")
            
    return cleaned_dfs, stats

# %%
cleaned_dfs, stats =  validate_and_clean_data(dfso, fk)
# Out:
# 🔍 order_items.order_id → orders.order_id
#    Найдено некорректных записей: 0 (0.0%)
# 🔍 order_items.product_id → products.product_id
#    Найдено некорректных записей: 1627 (1.4%)
# 🔍 order_items.seller_id → sellers.seller_id
#    Найдено некорректных записей: 0 (0.0%)
# ✅ order_items: Удалено 1627 записей
# 🔍 orders.customer_id → customers.customer_id
#    Найдено некорректных записей: 0 (0.0%)
# ✅ orders: Удалено 0 записей
# 🔍 order_reviews.order_id → orders.order_id
#    Найдено некорректных записей: 0 (0.0%)
# ✅ order_reviews: Удалено 0 записей
# 🔍 order_payments.order_id → orders.order_id
#    Найдено некорректных записей: 0 (0.0%)
# ✅ order_payments: Удалено 0 записей
# 🔍 closed_deals.seller_id → sellers.seller_id
#    Найдено некорректных записей: 462 (54.9%)
# ✅ closed_deals: Удалено 462 записей
# 🔍 marketing_qualified.mql_id → closed_deals.mql_id
#    Найдено некорректных записей: 7620 (95.2%)
# ✅ marketing_qualified: Удалено 7620 записей

# %% [markdown]
# ## 6. ☁️ Загрузка данных в Supabase (PostgreSQL)
#
# - Использование Python (например, через SQLAlchemy/`psycopg2`) для загрузки очищенных датафреймов.
# - Журналирование:
#   - лог успешной загрузки,
#   - контроль типов и размерностей.
# - Валидация:
#   - проверки внешних ключей (`customer_id`, `order_id`, `product_id`),
#   - проверка отсутствия дубликатов.
#
# 📌 _Цель: создать чистую, нормализованную, согласованную PostgreSQL-базу под аналитические запросы._
#
# ---

# %%
# pipeline.py

import pandas as pd
import re
from sqlalchemy import create_engine, text
from sqlalchemy.pool import NullPool
from sqlalchemy.exc import ProgrammingError
from dotenv import load_dotenv
import os
import time
from tqdm import tqdm

from src.db_utils import get_engine

# Используем заранее подготовленный скрипт для подключения к БД
engine = get_engine()

# === Утилиты === #
def map_dtype(dtype):
    if pd.api.types.is_string_dtype(dtype):
        return 'VARCHAR'
    elif pd.api.types.is_integer_dtype(dtype):
        return 'INTEGER'
    elif pd.api.types.is_float_dtype(dtype):
        return 'FLOAT'
    elif pd.api.types.is_bool_dtype(dtype):
        return 'BOOLEAN'
    elif pd.api.types.is_datetime64_any_dtype(dtype):
        return 'TIMESTAMP'
    else:
        return 'VARCHAR'

def to_snake_case(name):
    return re.sub(r'(?<!^)(?=[A-Z])', '_', name).lower().strip()

# === Генерация DDL === #
def generate_clean_ddl(df_dict, pk_dict):
    ddl_statements = {}
    for table_name, df in df_dict.items():
        table_snake = to_snake_case(table_name)
        lines = [f"CREATE TABLE IF NOT EXISTS {table_snake} ("]
        col_defs = []

        for col in df.columns:
            col_snake = to_snake_case(col)
            sql_type = map_dtype(df[col])
            col_defs.append(f"    {col_snake} {sql_type}")
        lines.extend([line + "," for line in col_defs])

        # Уточнённая логика добавления PK
        if table_name in pk_dict:
            pk_cols = [to_snake_case(col) for col in pk_dict[table_name]]
            pk_line = f"    PRIMARY KEY ({', '.join(pk_cols)})"
            lines.append(pk_line)

        lines[-1] = lines[-1].rstrip(",")
        lines.append(");")
        ddl_statements[table_snake] = "\n".join(lines)
    return ddl_statements

# === Создание таблиц === #
def create_tables_from_ddl(ddl_statements, engine):
    with engine.connect() as conn:
        for table, ddl in tqdm(ddl_statements.items(), desc="🔧 Creating tables"):
            try:
                conn.execute(text(ddl))
                print(f"✅ Created: {table}")
            except Exception as e:
                print(f"❌ Error creating table {table}: {e}")

# === Проверка на существование таблицы и данных === #
def table_has_data(table_name, engine):
    query = f"SELECT COUNT(*) FROM {table_name}"
    try:
        with engine.connect() as conn:
            result = conn.execute(text(query))
            count = result.scalar()
            return count > 0
    except ProgrammingError:
        return False  # таблицы ещё нет

# === Загрузка данных с проверкой === #
def upload_dfso_to_db_safe(df_dict, engine):
    for table_name, df in tqdm(df_dict.items(), desc="⬆️ Uploading data"):
        table_snake = to_snake_case(table_name)
        if table_has_data(table_snake, engine):
            print(f"⚠️ Skipping {table_snake} — already filled.")
            continue

        print(f"⬆️ Uploading: {table_snake}")
        try:
            df.columns = [to_snake_case(col) for col in df.columns]
            df.to_sql(
                table_snake,
                con=engine,
                if_exists='append',
                index=False,
                chunksize=1000
            )
            print(f"✅ Uploaded: {table_snake}")
        except Exception as e:
            print(f"❌ Error uploading {table_snake}: {e}")
            print("⏳ Waiting 10 seconds before retry...")
            time.sleep(10)
            try:
                df.to_sql(
                    table_snake,
                    con=engine,
                    if_exists='append',
                    index=False,
                    chunksize=1000
                )
                print(f"✅ Retried and uploaded: {table_snake}")
            except Exception as e:
                print(f"🚫 Second attempt failed for {table_snake}: {e}")

# === Финальная функция запуска === #
def run_full_pipeline(dfso, engine, pk_dict):
    print("📌 Starting pipeline...")
    ddl_dict = generate_clean_ddl(dfso, pk_dict)
    create_tables_from_ddl(ddl_dict, engine)
    upload_dfso_to_db_safe(dfso, engine)
    print("🏁 Pipeline completed.")

# %%
#from pipeline import run_full_pipeline, engine

pk = {
    "order_items": ["order_id", "order_item_id"],
    "orders": ["order_id"],
    "customers": ["customer_id"],
    "products": ["product_id"],
    "order_reviews": ["review_id"],
    "sellers": ["seller_id"],
    "closed_deals": ["mql_id"]
}

run_full_pipeline(dfso, engine, pk)
# Out:
# 📌 Starting pipeline...
# 🔧 Creating tables:  30%|██████████████████▉                                            | 3/10 [00:00<00:00, 12.09it/s]
# ✅ Created: closed_deals
# ✅ Created: customers
# ✅ Created: geolocation
# ✅ Created: marketing_qualified
# 🔧 Creating tables:  70%|████████████████████████████████████████████                   | 7/10 [00:00<00:00, 15.11it/s]
# ✅ Created: orders
# ✅ Created: order_items
# ✅ Created: order_payments
# ✅ Created: order_reviews
# 🔧 Creating tables: 100%|██████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 14.08it/s]
# ✅ Created: products
# ✅ Created: sellers
# ⬆️ Uploading data:  20%|████████████▊                                                   | 2/10 [00:00<00:01,  5.28it/s]
# ⚠️ Skipping closed_deals — already filled.
# ⚠️ Skipping customers — already filled.
# ⬆️ Uploading data:  30%|███████████████████▏                                            | 3/10 [00:00<00:01,  4.42it/s]
# ...

# %% [markdown]
# ### Выполним валидацию результатов

# %%
def validate_tables_exist(engine, table_names):
    with engine.connect() as conn:
        for table_name in table_names:
            result = conn.execute(text(f"SELECT to_regclass('{table_name}');"))
            if result.fetchone()[0] is None:
                print(f"❌ Table {table_name} does not exist.")
            else:
                print(f"✅ Table {table_name} exists.")
                
def validate_row_count(engine, df_dict):
    with engine.connect() as conn:
        for table_name, df in df_dict.items():
            table_snake = to_snake_case(table_name)
            result = conn.execute(text(f"SELECT COUNT(*) FROM {table_snake};"))
            db_row_count = result.fetchone()[0]
            df_row_count = len(df)
            if db_row_count == df_row_count:
                print(f"✅ Row count matches for {table_snake}: {db_row_count} rows.")
            else:
                print(f"❌ Row count mismatch for {table_snake}: Expected {df_row_count}, got {db_row_count}.")
                
def validate_data_types(engine, df_dict):
    with engine.connect() as conn:
        for table_name, df in df_dict.items():
            table_snake = to_snake_case(table_name)
            for col in df.columns:
                col_snake = to_snake_case(col)
                # Получаем тип данных из базы данных
                result = conn.execute(text(f"SELECT data_type FROM information_schema.columns WHERE table_name = '{table_snake}' AND column_name = '{col_snake}';"))
                db_data_type = result.fetchone()[0]
                # Проверяем соответствие типов данных
                expected_type = map_dtype(df[col])
                if db_data_type.lower() == expected_type.lower():
                    print(f"✅ Data type matches for {table_snake}.{col_snake}: {db_data_type}.")
                else:
                    print(f"❌ Data type mismatch for {table_snake}.{col_snake}: Expected {expected_type}, got {db_data_type}.")
                
def validate_data_types(engine, df_dict):
    with engine.connect() as conn:
        for table_name, df in df_dict.items():
            table_snake = to_snake_case(table_name)
            for col in df.columns:
                col_snake = to_snake_case(col)
                
                # Проверяем существование колонки
                col_exists = conn.execute(text(
                    f"SELECT EXISTS ("
                    f"SELECT 1 FROM information_schema.columns "
                    f"WHERE table_name = '{table_snake}' "
                    f"AND column_name = '{col_snake}'"
                    f");"
                )).scalar()
                
                if not col_exists:
                    print(f"⚠️ Column {table_snake}.{col_snake} does not exist in DB")
                    continue
                
                # Получаем тип данных из БД
                result = conn.execute(text(
                    f"SELECT data_type FROM information_schema.columns "
                    f"WHERE table_name = '{table_snake}' "
                    f"AND column_name = '{col_snake}';"
                ))
                db_data_type = result.fetchone()[0].lower()
                
                # Уточнённый маппинг типов
                dtype_map = {
                    'object': 'text',
                    'int64': 'integer',
                    'float64': 'double precision',
                    'bool': 'boolean',
                    'datetime64[ns]': 'timestamp without time zone'
                }
                expected_type = dtype_map.get(str(df[col].dtype), 'text')
                
                # Нормализация названий типов
                type_aliases = {
                    'varchar': 'text',
                    'timestamp': 'timestamp without time zone'
                }
                db_data_type = type_aliases.get(db_data_type, db_data_type)
                
                if db_data_type == expected_type:
                    print(f"✅ {table_snake}.{col_snake}: {db_data_type}")
                else:
                    print(f"❌ {table_snake}.{col_snake}: "
                          f"DB имеет {db_data_type}, ожидался {expected_type}")

def validate_missing_values(engine, df_dict):
    with engine.connect() as conn:
        for table_name, df in df_dict.items():
            table_snake = to_snake_case(table_name)
            for col in df.columns:
                col_snake = to_snake_case(col)
                # Проверяем наличие пропусков в базе данных
                result = conn.execute(text(f"SELECT COUNT(*) FROM {table_snake} WHERE {col_snake} IS NULL;"))
                db_null_count = result.fetchone()[0]
                df_null_count = df[col].isnull().sum()
                if db_null_count == df_null_count:
                    print(f"✅ Missing values match for {table_snake}.{col_snake}: {db_null_count} missing values.")
                else:
                    print(f"❌ Missing values mismatch for {table_snake}.{col_snake}: Expected {df_null_count}, got {db_null_count}.")
                    
                    
                    
def validate_primary_keys(engine, df_dict):
    with engine.connect() as conn:
        for table_name, df in df_dict.items():
            table_snake = to_snake_case(table_name)
            # Пример для первичного ключа
            primary_key_col = f"{table_snake[:-1]}_id"  # Предполагаем, что первичный ключ имеет такое название
            if primary_key_col in [to_snake_case(c) for c in df.columns]:
                result = conn.execute(text(f"SELECT COUNT(DISTINCT {primary_key_col}) FROM {table_snake};"))
                db_unique_count = result.fetchone()[0]
                df_unique_count = df[primary_key_col].nunique()
                if db_unique_count == df_unique_count:
                    print(f"✅ Unique values match for {table_snake}.{primary_key_col}: {db_unique_count} unique values.")
                else:
                    print(f"❌ Unique values mismatch for {table_snake}.{primary_key_col}: Expected {df_unique_count}, got {db_unique_count}.")

                    
def run_validation(dfso, engine):
    print("📌 Starting validation...")
    table_names = [to_snake_case(table_name) for table_name in dfso.keys()]
    
    # Проверка наличия таблиц
    validate_tables_exist(engine, table_names)
    
    # Проверка количества строк
    validate_row_count(engine, dfso)
    
    # Проверка типов данных
    validate_data_types(engine, dfso)
    
    # Проверка пропусков
    validate_missing_values(engine, dfso)
    
    # Проверка уникальности первичных ключей
    validate_primary_keys(engine, dfso)

    print("🏁 Validation completed.")

# %%
run_validation(dfso, engine)
# Out:
# 📌 Starting validation...
# ✅ Table closed_deals exists.
# ✅ Table customers exists.
# ✅ Table geolocation exists.
# ✅ Table marketing_qualified exists.
# ✅ Table orders exists.
# ✅ Table order_items exists.
# ✅ Table order_payments exists.
# ✅ Table order_reviews exists.
# ✅ Table products exists.
# ✅ Table sellers exists.
# ✅ Row count matches for closed_deals: 842 rows.
# ✅ Row count matches for customers: 99441 rows.
# ✅ Row count matches for geolocation: 738332 rows.
# ✅ Row count matches for marketing_qualified: 8000 rows.
# ✅ Row count matches for orders: 99441 rows.
# ✅ Row count matches for order_items: 112650 rows.
# ✅ Row count matches for order_payments: 103886 rows.
# ✅ Row count matches for order_reviews: 99224 rows.
# ✅ Row count matches for products: 32328 rows.
# ✅ Row count matches for sellers: 3095 rows.
# ✅ closed_deals.mql_id: text
# ✅ closed_deals.seller_id: text
# ✅ closed_deals.sdr_id: text
# ✅ closed_deals.sr_id: text
# ...

# %% [markdown]
# ## ✅ Вывод
#
# На выходе мы получаем:
# - чистые и обогащённые датафреймы,
# - корректную схему с ключами и типами,
# - загруженные данные в Supabase, готовые к написанию SQL-скриптов, агрегаций и построению витрин.
#
# Следующим этапом станет **аналитическая трансформация и создание витрин**, на которых будут построены ключевые продуктовые метрики.

# %%
import os
from dotenv import load_dotenv
import subprocess

load_dotenv()

user = os.getenv("user")
password = os.getenv("password")
host = os.getenv("host")
port = os.getenv("port")
dbname = os.getenv("dbname")

db_url = f"postgresql+psycopg2://{user}:{password}@{host}:{port}/{dbname}"

# 1. Генерация .dot-файла
subprocess.run(["eralchemy", "-i", db_url, "-o", "schema.dot", "--exclude-tables", "^pg_.*,^sql_.*"])

# 2. Конвертация в картинку
subprocess.run(["dot", "-Tpng", "schema.dot", "-o", "schema.png"])

print("✅ ER-диаграмма сохранена как schema.png")
# Out:
# ✅ ER-диаграмма сохранена как schema.png

# %%
dfso['marketing_qualified'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   mql_id              8000 non-null   object
#  1   first_contact_date  8000 non-null   datetime64[ns]
#  2   landing_page_id     8000 non-null   object
#  3   origin              8000 non-null   category
# dtypes: category(1), datetime64[ns](1), object(2)
# memory usage: 195.8+ KB

# %%
dfso['closed_deals'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 842 entries, 0 to 841
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   mql_id                         842 non-null    object
#  1   seller_id                      842 non-null    object
#  2   sdr_id                         842 non-null    object
#  3   sr_id                          842 non-null    object
#  4   won_date                       842 non-null    datetime64[ns]
#  5   business_segment               842 non-null    category
#  6   lead_type                      842 non-null    category
#  7   lead_behaviour_profile         842 non-null    category
#  8   has_company                    842 non-null    bool
#  9   has_gtin                       842 non-null    bool
#  10  business_type                  842 non-null    category
#  11  declared_product_catalog_size  69 non-null     float64
# ...
